# %% [markdown]
# __LINE PLOT__

# %%
import seaborn as sns
import pandas as pd

data = { "Days" : ["Day1", "Day2","Day3","Day4","Day5","Day6"],
        "NOP" :[64,26,45,34,65,15]
}

df = pd.DataFrame(data)

print(df)

sns.lineplot(data=df, x = "Days", y="NOP")
# Out:
#    Days  NOP
# 0  Day1   64
# 1  Day2   26
# 2  Day3   45
# 3  Day4   34
# 4  Day5   65
# 5  Day6   15
# <Axes: xlabel='Days', ylabel='NOP'>

# %% [markdown]
# __LINE PLOT WITH DATASET__

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_excel("payments.xlsx")

sns.lineplot(data=data , x= "Category" , y= "Amount", hue = "Payment_Method", marker = "o", palette = "viridis")
# Out:
# <Axes: xlabel='Category', ylabel='Amount'>

# %% [markdown]
# __BAR PLOT__

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

data = sns.load_dataset("tips")
print(data)
sns.barplot(data = data , x = "day", y = "tip", hue = "sex", palette = "viridis")
plt.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# __HISTOGRAM PLOT__

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data = sns.load_dataset("titanic")
print(data)
sns.histplot(data = data, x = "age", hue = "who", kde = True, palette = "viridis")
plt.show()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# __SCATTER PLOT__

# %%
import matplotlib.pyplot as plt
import seaborn as sns

data = sns.load_dataset("tips")
print(data)
sns.scatterplot(data = data , x = "total_bill", y = "tip", hue = "day", palette = "rocket")
plt.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# __HEAT MAP__

# %%
import matplotlib.pyplot as plt
import seaborn as sns

data = sns.load_dataset("tips")
print(data)
group = data.groupby("day").agg({"tip" : "median"})
print(group)
sns.heatmap(group)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
#         tip
# day
# Thur  2.305
# Fri   3.000
# Sat   2.750
# Sun   3.150
# ...

# %% [markdown]
# __COUNT PLOT__

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data = sns.load_dataset("tips")
print(data)
sns.countplot(data = data, x = "day" , hue = "smoker", palette = "viridis", legend = True)
plt.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# __VIOLIN PLOT__

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data = sns.load_dataset("titanic")
print(data)

sns.violinplot(data = data, x = "age", hue = "sex", palette = "rocket")
plt.show()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# __PAIR PLOT__

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data = sns.load_dataset("tips")

sns.pairplot(data, hue = "sex", palette = "rocket")
plt.show()

# %% [markdown]
# __STRIP PLOT__

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data = sns.load_dataset("tips")
# print(data)
sns.stripplot(data = data, x = "day", y = "tip" , hue = "sex", dodge = True, palette = "rocket")
plt.show()

# %% [markdown]
# __BOX PLOT__

# %%
import matplotlib.pyplot as plt
import seaborn as sns

data = sns.load_dataset("tips")
print(data)

sns.boxplot(data = data, x = "tip", y = "day" , hue = "sex", palette = "viridis")
plt.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# __CATEGORICAL PLOT__

# %%
import matplotlib.pyplot as plt
import seaborn as sns

data = sns.load_dataset("tips")
print(data)

sns.catplot(data = data, x = "total_bill", y = "day", hue = "sex", kind = "violin", palette = "GnBu")  #kind use for different charts
plt.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# __MULTIPLE PLOT__

# %%
import matplotlib.pyplot as plt
import seaborn as sns

data = sns.load_dataset("tips")
print(data)
a = sns.FacetGrid(data, col = "smoker", height = 4, hue = "sex", palette = "viridis")
a.map(sns.scatterplot,"day", "tip")
plt.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# __RELATION PLOT__

# %%
import matplotlib.pyplot as plt
import seaborn as sns 

data = sns.load_dataset("tips")
print(data)

sns.relplot(data = data , x = "tip", y = "total_bill", hue = "sex" , col = "time" , palette = "viridis")
plt.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# __SWARM PLOT__

# %%
import matplotlib.pyplot as plt
import seaborn as sns 

data = sns.load_dataset("tips")
#print(data)

sns.swarmplot(data = data , x = "day", y = "tip", hue = "sex" , palette = "rocket")
plt.show()

# %% [markdown]
# __KDE (Kernel Density Estimate) PLOT__

# %%
import matplotlib.pyplot as plt
import seaborn as sns 

data = sns.load_dataset("tips")
print(data)
sns.kdeplot(data = data, x= "total_bill", hue = "day", multiple = "stack", palette = "GnBu")
plt.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
